# %%
from utils.global_functions import simulation
simulation(scenario='skyalp', graph='all', Pathway_Feedstock='FT - Lignocellulose')
# Out:
# 'Simulation successful'

# %%
import pandas as pd
SAF_prices = pd.read_excel('utils/Base prix.xlsx', usecols=[2], sheet_name='Price', header=0).iloc[4:19]
SAF_prices
# Out:
#                          Pathway_Feedstock
# 4                      HEFA - Camelina oil
# 5                       HEFA - Soybean oil
# 6                          HEFA - Jatropha
# 7        HEFA - Waste oils and animal fats
# 8                        CH - Camelina oil
# 9                      CH - Lignocellulose
# 10                   HDCJ - Lignocellulose
# 11                     FT - Lignocellulose
# 12                        ATJ - Sugar cane
# 13                        ATJ - Corn grain
# 14     ATJ - Lignocellulose (biochemistry)
# 15  ATJ - Lignocellulose (thermochemistry)
# 16                       DSHC - Sugar cane
# 17                   DSHC - Lignocellulose
# 18                    APR - Lignocellulose
